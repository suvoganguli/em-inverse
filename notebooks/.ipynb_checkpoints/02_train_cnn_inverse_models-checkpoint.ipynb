# %% [markdown]
# # 02 — CNN Models for Maxwell Inverse Prediction
#
# This notebook trains convolutional neural networks on three Maxwell-generated datasets:
#
# - `xy`
# - `xyr`
# - `xyrc`
#
# Each model takes multistatic complex measurement tensors as input and predicts the unknown tumor parameters.
#
# The main goal is to compare inverse-learning performance as the dimension of the unknown parameter vector increases.

# %%
# =========================================================
# Imports
# =========================================================
import os
import sys
import copy
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# allow notebook to import from project root
sys.path.append(os.path.abspath(".."))

from config import load_npz, normalize_targets, denormalize_targets, savefig

# %%
# =========================================================
# Device
# =========================================================
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: mps

# %%
# =========================================================
# Load datasets
# =========================================================
data_xy = load_npz("data_xy")
data_xyr = load_npz("data_xyr")
data_xyrc = load_npz("data_xyrc")

X_xy, y_xy = data_xy["X"], data_xy["y"]
X_xyr, y_xyr = data_xyr["X"], data_xyr["y"]
X_xyrc, y_xyrc = data_xyrc["X"], data_xyrc["y"]

print("XY   :", X_xy.shape, y_xy.shape)
print("XYR  :", X_xyr.shape, y_xyr.shape)
print("XYRC :", X_xyrc.shape, y_xyrc.shape)
# Out:
# XY   : (100, 16, 16, 2) (100, 2)
# XYR  : (200, 16, 16, 2) (200, 3)
# XYRC : (300, 16, 16, 2) (300, 4)

# %%
# =========================================================
# Train/val/test split helper
# =========================================================
def split_dataset(X, y, train_frac=0.7, val_frac=0.15, seed=123):
    rng = np.random.default_rng(seed)
    n = len(X)
    idx = rng.permutation(n)

    n_train = int(train_frac * n)
    n_val = int(val_frac * n)

    idx_train = idx[:n_train]
    idx_val = idx[n_train:n_train + n_val]
    idx_test = idx[n_train + n_val:]

    return (
        X[idx_train], y[idx_train],
        X[idx_val], y[idx_val],
        X[idx_test], y[idx_test]
    )

# %%
# =========================================================
# Tensor preparation helper
# Converts (N, H, W, C) -> (N, C, H, W)
# =========================================================
def prepare_tensors(X, y):
    X_t = torch.tensor(np.transpose(X, (0, 3, 1, 2)), dtype=torch.float32)
    y_t = torch.tensor(normalize_targets(y), dtype=torch.float32)
    return X_t, y_t

# %%
# =========================================================
# Compact CNN regressor
# =========================================================
class InverseCNN(nn.Module):
    def __init__(self, out_dim):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(2, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((2, 2))
        )

        self.regressor = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 2 * 2, 64),
            nn.ReLU(),
            nn.Linear(64, out_dim)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.regressor(x)
        return x

# %%
# =========================================================
# Simple MLP regressor (flattened input)
# =========================================================
class InverseMLP(nn.Module):
    def __init__(self, out_dim):
        super().__init__()

        self.net = nn.Sequential(
            nn.Flatten(),

            nn.Linear(16*16*2, 256),
            nn.ReLU(),

            nn.Linear(256, 128),
            nn.ReLU(),

            nn.Linear(128, 64),
            nn.ReLU(),

            nn.Linear(64, out_dim)
        )

    def forward(self, x):
        return self.net(x)

# %%
# =========================================================
# Weighted multi-output MSE loss
# =========================================================
class WeightedMSELoss(nn.Module):
    def __init__(self, weights):
        super().__init__()
        self.register_buffer("weights", torch.tensor(weights, dtype=torch.float32))

    def forward(self, pred, target):
        loss_per_dim = (pred - target) ** 2
        weighted = loss_per_dim * self.weights
        return weighted.mean()

# %%
# =========================================================
# Training helper
# =========================================================
def train_model(X, y, out_dim, epochs=80, batch_size=16, lr=1e-3, seed=123, loss_weights=None, model_type="cnn"):
    X_train, y_train, X_val, y_val, X_test, y_test = split_dataset(X, y, seed=seed)

    X_train_t, y_train_t = prepare_tensors(X_train, y_train)
    X_val_t, y_val_t = prepare_tensors(X_val, y_val)
    X_test_t, y_test_t = prepare_tensors(X_test, y_test)

    train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val_t, y_val_t), batch_size=batch_size, shuffle=False)

    model_type = "mpl"
    if model_type == "cnn":
        model = InverseCNN(out_dim=out_dim).to(device)
    elif model_type == "mlp":
        model = InverseMLP(out_dim=out_dim).to(device)

    if loss_weights is None:
        criterion = nn.MSELoss()
    else:
        criterion = WeightedMSELoss(loss_weights).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    best_val = np.inf
    best_state = None

    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0

        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)

            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * xb.size(0)

        train_loss /= len(train_loader.dataset)

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                pred = model(xb)
                loss = criterion(pred, yb)
                val_loss += loss.item() * xb.size(0)

        val_loss /= len(val_loader.dataset)

        train_losses.append(train_loss)
        val_losses.append(val_loss)

        if val_loss < best_val:
            best_val = val_loss
            best_state = copy.deepcopy(model.state_dict())

        if (epoch + 1) % 10 == 0 or epoch == 0:
            print(f"Epoch {epoch+1:3d}/{epochs} | train={train_loss:.6f} | val={val_loss:.6f}")

    model.load_state_dict(best_state)
    model.eval()

    with torch.no_grad():
        y_pred_test = model(X_test_t.to(device)).cpu().numpy()

    y_pred_test = denormalize_targets(y_pred_test)
    y_test_true = y_test.copy()

    return {
        "model": model,
        "train_losses": train_losses,
        "val_losses": val_losses,
        "X_test": X_test,
        "y_test": y_test_true,
        "y_pred": y_pred_test,
    }
# Out:
#   Cell In[48], line 5
#     X_train, y_train, X_val, y_val, X_test, y_test = split_dataset(X, y, seed=seed, model_type="cnn"):
#                                                                                                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Train CNN for `xy`
#
# Predict tumor center `(x, y)` from Maxwell measurement tensors.

# %%
# =========================================================
# Train XY model
# =========================================================
results_xy = train_model(
    X_xy, y_xy,
    out_dim=2,
    epochs=80,
    batch_size=16,
    lr=1e-3,
    seed=101
)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[46], line 4
#       1 # =========================================================
#       2 # Train XY model
#       3 # =========================================================
# ----> 4 results_xy = train_model(
#       5     X_xy, y_xy,
#       6     out_dim=2,
#       7     epochs=80,
#
# Cell In[45], line 25, in train_model(X, y, out_dim, epochs, batch_size, lr, seed, loss_weights)
#      21         criterion = nn.MSELoss()
#      22     else:
#      23         criterion = WeightedMSELoss(loss_weights).to(device)
#      24
# ---> 25     optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#      26
#      27     best_val = np.inf
#      28     best_state = None
#
# UnboundLocalError: cannot access local variable 'model' where it is not associated with a value

# %% [markdown]
# ## Train CNN for `xyr`
#
# Predict tumor center and radius `(x, y, r)` from Maxwell measurement tensors.

# %%
# =========================================================
# Train XYR model
# =========================================================
results_xyr = train_model(
    X_xyr, y_xyr,
    out_dim=3,
    epochs=80,
    batch_size=16,
    lr=1e-3,
    seed=102
)
# Out:
# Epoch   1/80 | train=0.316781 | val=0.270571
# Epoch  10/80 | train=0.160748 | val=0.144840
# Epoch  20/80 | train=0.059618 | val=0.057689
# Epoch  30/80 | train=0.037188 | val=0.035372
# Epoch  40/80 | train=0.029562 | val=0.029367
# Epoch  50/80 | train=0.025964 | val=0.024839
# Epoch  60/80 | train=0.025183 | val=0.023557
# Epoch  70/80 | train=0.023360 | val=0.020405
# Epoch  80/80 | train=0.022391 | val=0.020789

# %% [markdown]
# ## Train CNN for `xyrc`
#
# Predict tumor center, radius, and contrast `(x, y, r, c)` from Maxwell measurement tensors.

# %%
# =========================================================
# Train XYRC model
# =========================================================
results_xyrc = train_model(
    X_xyrc, y_xyrc,
    out_dim=4,
    epochs=80,
    batch_size=16,
    lr=1e-3,
    seed=103
)
# Out:
# Epoch   1/80 | train=0.306051 | val=0.231396
# Epoch  10/80 | train=0.110672 | val=0.101007
# Epoch  20/80 | train=0.046389 | val=0.048066
# Epoch  30/80 | train=0.035759 | val=0.033505
# Epoch  40/80 | train=0.029109 | val=0.031933
# Epoch  50/80 | train=0.027653 | val=0.032499
# Epoch  60/80 | train=0.025191 | val=0.028922
# Epoch  70/80 | train=0.024621 | val=0.028799
# Epoch  80/80 | train=0.024571 | val=0.028976

# %%
# =========================================================
# Retrain XYRC with weighted loss
# More emphasis on x, y
# =========================================================
results_xyrc_w = train_model(
    X_xyrc, y_xyrc,
    out_dim=4,
    epochs=80,
    batch_size=16,
    lr=1e-3,
    seed=103,
    loss_weights=[2.0, 2.0, 1.0, 1.0]
)
# Out:
# Epoch   1/80 | train=0.513778 | val=0.390134
# Epoch  10/80 | train=0.160399 | val=0.138322
# Epoch  20/80 | train=0.071689 | val=0.079201
# Epoch  30/80 | train=0.045514 | val=0.044041
# Epoch  40/80 | train=0.037548 | val=0.038250
# Epoch  50/80 | train=0.034860 | val=0.035807
# Epoch  60/80 | train=0.032845 | val=0.034761
# Epoch  70/80 | train=0.031900 | val=0.036581
# Epoch  80/80 | train=0.029125 | val=0.033933

# %%
# =========================================================
# Plot training curves
# =========================================================
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].plot(results_xy["train_losses"], label="train")
axes[0].plot(results_xy["val_losses"], label="val")
axes[0].set_title("XY Loss")
axes[0].set_xlabel("Epoch")
axes[0].legend()

axes[1].plot(results_xyr["train_losses"], label="train")
axes[1].plot(results_xyr["val_losses"], label="val")
axes[1].set_title("XYR Loss")
axes[1].set_xlabel("Epoch")
axes[1].legend()

axes[2].plot(results_xyrc["train_losses"], label="train")
axes[2].plot(results_xyrc["val_losses"], label="val")
axes[2].set_title("XYRC Loss")
axes[2].set_xlabel("Epoch")
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
# =========================================================
# Compute test errors (denormalized)
# =========================================================
def compute_errors(results, name):
    y_true = results["y_test"]
    y_pred = results["y_pred"]

    err = np.abs(y_pred - y_true)

    print(f"\n{name} errors:")
    print("Mean absolute error:", err.mean(axis=0))
    print("Std:", err.std(axis=0))

    return err

err_xy = compute_errors(results_xy, "XY")
err_xyr = compute_errors(results_xyr, "XYR")
err_xyrc = compute_errors(results_xyrc, "XYRC")
# Out:
# XY errors:
# Mean absolute error: [0.00462384 0.00451346]
# Std: [0.00639828 0.00462815]
#
# XYR errors:
# Mean absolute error: [0.00549133 0.00562102 0.00267988]
# Std: [0.00567698 0.00442167 0.00202838]
#
# XYRC errors:
# Mean absolute error: [6.8482761e-03 5.7712500e-03 3.5720076e-03 1.0432848e+01]
# Std: [5.7817223e-03 5.3914776e-03 2.1273291e-03 5.8964005e+00]

# %%
# =========================================================
# XY scatter (true vs predicted)
# =========================================================
def plot_xy(results, title):
    y_true = results["y_test"]
    y_pred = results["y_pred"]

    plt.figure(figsize=(5,5))
    plt.scatter(y_true[:,0], y_true[:,1], label="True", alpha=0.6)
    plt.scatter(y_pred[:,0], y_pred[:,1], label="Pred", alpha=0.6)

    plt.xlabel("x")
    plt.ylabel("y")
    plt.title(title)
    plt.legend()
    plt.axis("equal")
    plt.show()

plot_xy(results_xy, "XY Prediction")
plot_xy(results_xyr, "XYR Prediction (XY part)")
plot_xy(results_xyrc, "XYRC Prediction (XY part)")

# %%
 print(np.linalg.norm(results_xy["y_pred"] - results_xy["y_test"], axis=1))
# Out:
# [0.01825247 0.00365494 0.02405222 0.00073318 0.00270796 0.00258278
#  0.01172426 0.00286562 0.00621761 0.00262272 0.00625593 0.00348316
#  0.00352756 0.01893624 0.00292758]

# %%
# =========================================================
# Physical RMSE / MAE by variable
# =========================================================
def summarize_results(results, name):
    y_true = results["y_test"]
    y_pred = results["y_pred"]

    err = y_pred - y_true
    mae = np.mean(np.abs(err), axis=0)
    rmse = np.sqrt(np.mean(err**2, axis=0))

    print(f"\n{name}")
    print("MAE :", mae)
    print("RMSE:", rmse)

summarize_results(results_xy, "XY")
summarize_results(results_xyr, "XYR")
summarize_results(results_xyrc, "XYRC")
# Out:
# XY
# MAE : [0.00462384 0.00451346]
# RMSE: [0.00789417 0.0064646 ]
#
# XYR
# MAE : [0.00549133 0.00562102 0.00267988]
# RMSE: [0.00789828 0.00715172 0.00336097]
#
# XYRC
# MAE : [6.8482761e-03 5.7712500e-03 3.5720076e-03 1.0432848e+01]
# RMSE: [8.9625437e-03 7.8978073e-03 4.1574957e-03 1.1983817e+01]

# %%
# =========================================================
# XY error vectors
# =========================================================
def plot_xy_quiver(results, title):
    y_true = results["y_test"]
    y_pred = results["y_pred"]

    dx = y_pred[:, 0] - y_true[:, 0]
    dy = y_pred[:, 1] - y_true[:, 1]

    plt.figure(figsize=(6, 6))
    plt.scatter(y_true[:, 0], y_true[:, 1], c="blue", label="True", alpha=0.7)
    plt.quiver(
        y_true[:, 0], y_true[:, 1],
        dx, dy,
        angles='xy', scale_units='xy', scale=1,
        color='orange', alpha=0.8
    )
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title(title)
    plt.axis("equal")
    plt.legend()
    plt.show()

plot_xy_quiver(results_xy, "XY error vectors")
plot_xy_quiver(results_xyr, "XYR error vectors")
plot_xy_quiver(results_xyrc, "XYRC error vectors")

# %%
# =========================================================
# Tiny-set overfit helper: train = evaluate on same data
# =========================================================
def train_model_overfit(X, y, out_dim, epochs=300, batch_size=10, lr=1e-3):
    X_t, y_t = prepare_tensors(X, y)
    loader = DataLoader(TensorDataset(X_t, y_t), batch_size=batch_size, shuffle=True)

    model = InverseCNN(out_dim=out_dim).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    losses = []

    for epoch in range(epochs):
        model.train()
        running = 0.0

        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)

            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()

            running += loss.item() * xb.size(0)

        epoch_loss = running / len(loader.dataset)
        losses.append(epoch_loss)

        if (epoch + 1) % 20 == 0 or epoch == 0:
            print(f"Epoch {epoch+1:3d}/{epochs} | loss={epoch_loss:.6f}")

    model.eval()
    with torch.no_grad():
        y_pred = model(X_t.to(device)).cpu().numpy()

    y_pred = denormalize_targets(y_pred)

    return {
        "model": model,
        "losses": losses,
        "y_test": y.copy(),
        "y_pred": y_pred,
    }

# %%
# =========================================================
# Tiny subset helper
# =========================================================
def take_subset(X, y, n_samples=10, seed=999):
    rng = np.random.default_rng(seed)
    idx = rng.choice(len(X), size=n_samples, replace=False)
    return X[idx], y[idx]

# %%
# =========================================================
# True tiny-set overfit test for XY
# =========================================================
X_xy_tiny, y_xy_tiny = take_subset(X_xy, y_xy, n_samples=10, seed=999)

results_xy_tiny = train_model_overfit(
    X_xy_tiny, y_xy_tiny,
    out_dim=2,
    epochs=400,
    batch_size=10,
    lr=1e-3
)
# Out:
# Epoch   1/400 | loss=0.337526
# Epoch  20/400 | loss=0.285289
# Epoch  40/400 | loss=0.281960
# Epoch  60/400 | loss=0.271275
# Epoch  80/400 | loss=0.146953
# Epoch 100/400 | loss=0.108969
# Epoch 120/400 | loss=0.088313
# Epoch 140/400 | loss=0.072907
# Epoch 160/400 | loss=0.063157
# Epoch 180/400 | loss=0.055398
# Epoch 200/400 | loss=0.044231
# Epoch 220/400 | loss=0.028148
# Epoch 240/400 | loss=0.014620
# Epoch 260/400 | loss=0.009543
# Epoch 280/400 | loss=0.007415
# Epoch 300/400 | loss=0.005890
# Epoch 320/400 | loss=0.004934
# Epoch 340/400 | loss=0.004471
# Epoch 360/400 | loss=0.003609
# Epoch 380/400 | loss=0.003190
# Epoch 400/400 | loss=0.002822

# %%
# =========================================================
# Overfit loss curve
# =========================================================
plt.figure(figsize=(6,4))
plt.plot(results_xy_tiny["losses"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Tiny-set XY true overfit test")
plt.show()

# %%
plot_xy_quiver(results_xy_tiny, "Tiny-set XY true overfit")
summarize_results(results_xy_tiny, "Tiny-set XY true overfit")
# Out:
# Tiny-set XY true overfit
# MAE : [0.00173727 0.0023997 ]
# RMSE: [0.00226835 0.0038882 ]
